# %%
using PyPlot

ts_length = 100
epsilon_values = randn(ts_length)
plot(epsilon_values, "b-")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002FDEB390>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x000000002FE96CC0>

# %%
typeof(epsilon_values)
# Out:
# Array{Float64,1}

# %%
epsilon_values
# Out:
# 100-element Array{Float64,1}:
#  -0.943736
#  -1.04581
#  -0.914037
#   0.494862
#  -1.73843
#   0.877441
#   2.24295
#   0.875132
#   1.311
#  -0.246881
#  -0.642769
#   0.704153
#  -0.98626
#   ⋮
#  -1.41627
#  -0.17037
#  -0.865569
#  -0.471284
#  -0.217365
#  -1.58647
#   0.255657
#   0.237878
#   0.709953
#  -0.0879759
#   1.18578
#  -0.300529

# %%
x = [10, "Foo", false]
println(typeof(x))
println(length(x), " ", x)
for i in 1:3
    println("$i, $(x[i]), $(typeof(x[i]))")
end
# Out:
# Array{Any,1}
# 3 {10,"Foo",false}
# 1, 10, Int64
# 2, Foo, ASCIIString
# 3, false, Bool

# %%
println(pop!(x))
println(x)
# Out:
# false
# {10,"Foo"}

# %%
println(push!(x, "bar"))
# Out:
# {10,"Foo","bar"}

# %%
words = ["foo", "bar"]
for word in words
    println("Hello $word")
end
# Out:
# Hello foo
# Hello bar

# %%
using Distributions

function plot_hist(dist, n)
    x = rand(dist, n)
    PyPlot.plt.hist(x)
end

lp = Laplace()
plot_hist(lp, 500)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000002FEAAC18>)
# ([2.0,0.0,4.0,21.0,66.0,236.0,127.0,36.0,7.0,1.0],[-7.96288,-6.57271,-5.18253,-3.79235,-2.40217,-1.01199,0.378188,1.76837,3.15854,4.54872,5.9389],{PyObject <matplotlib.patches.Rectangle object at 0x00000000301A4358>,PyObject <matplotlib.patches.Rectangle object at 0x00000000301A48D0>,PyObject <matplotlib.patches.Rectangle object at 0x00000000301A4E80>,PyObject <matplotlib.patches.Rectangle object at 0x00000000301B2470>,PyObject <matplotlib.patches.Rectangle object at 0x00000000301B2A20>,PyObject <matplotlib.patches.Rectangle object at 0x00000000301B2FD0>,PyObject <matplotlib.patches.Rectangle object at 0x00000000301C15C0>,PyObject <matplotlib.patches.Rectangle object at 0x00000000301C1B70>,PyObject <matplotlib.patches.Rectangle object at 0x00000000301C1FD0>,PyObject <matplotlib.patches.Rectangle object at 0x00000000301D1710>})

# %%
rand(3)
# Out:
# 3-element Array{Float64,1}:
#  0.534317
#  0.218794
#  0.733503

# %%
x = randn(100)
plot(x, "b-", label="White noise")
legend()
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x00000000302E2C18>)
# PyObject <matplotlib.legend.Legend object at 0x0000000030516160>

# %%
x = true
println(typeof(x))
# Out:
# Bool

# %%
y = 1 > 2
println(y)
# Out:
# false

# %%
println(true + false)
# Out:
# 1

# %%
println(sum([true, false, false, true]))
# Out:
# 2

# %% [markdown]
# ##Expressions

# %%
x = 2; y = 1.0
# Out:
# 1.0

# %%
x * y
# Out:
# 2.0

# %%
x^2
# Out:
# 4

# %%
y / x
# Out:
# 0.5

# %%
2x - 3y
# Out:
# 1.0

# %%
+(10, 20)
# Out:
# 30

# %%
x = 1 + 2im
# Out:
# 1 + 2im

# %%
println(typeof(x))
# Out:
# Complex{Int64}

# %%
y = 1 - 2im
z = x * y
println(typeof(z), ", ", z)
# Out:
# Complex{Int64}, 5 + 0im

# %%
x = "foobar"
println(typeof(x))
# Out:
# ASCIIString

# %%
x = 10; y = 20
"x = $x"
# Out:
# "x = 10"

# %%
"foo" * "bar"
# Out:
# "foobar"

# %%
s1 = "Chalie don't surf"
split(s1)
# Out:
# 3-element Array{SubString{ASCIIString},1}:
#  "Chalie"
#  "don't"
#  "surf"

# %%
s2 = replace(s1, "surf", "ski")
println(s1)
println(s2)
# Out:
# Chalie don't surf
# Chalie don't ski

# %%
split("fee,fi,fo", ",")
# Out:
# 3-element Array{SubString{ASCIIString},1}:
#  "fee"
#  "fi"
#  "fo"

# %%
strip(" foobar ")
# Out:
# "foobar"
