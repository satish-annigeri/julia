# %%
using PyPlot

x = linspace(0, 2*pi, 201)
y = sin(x)
plot(x, y)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000001E51B470>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x000000001E698CF8>
